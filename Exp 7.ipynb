# %%
#print all colors from colorset 1 not contained in color set 2
set1=set(input("enter color in set 1:").split(","))
set2=set(input("enter color in set 2:").split(","))
print("set 1=",set1)
print("set 2=",set2)
result=set1-set2
print("colors not contained in color set 2:",result)
# Out:
# enter color in set 1: red,yellow,green
# enter color in set 2: red,blue,yellow
# set 1= {'red', 'yellow', 'green'}
# set 2= {'red', 'blue', 'yellow'}
# colors not contained in color set 2: {'green'}

# %%
#print all colors from colorset 1 and color set 2
set1=set(input("enter color in set 1:").split(","))
set2=set(input("enter color in set 2:").split(","))
print("set 1=",set1)
print("set 2=",set2)
result=set1|set2
print("colors contained in color set1 and set 2:",result)
# Out:
# enter color in set 1: red,blue,pink
# enter color in set 2: lavender,black,white
# set 1= {'blue', 'red', 'pink'}
# set 2= {'white', 'lavender', 'black'}
# colors contained in color set1 and set 2: {'blue', 'white', 'lavender', 'pink', 'black', 'red'}
